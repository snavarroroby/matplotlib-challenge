# %% [markdown]
# ## Observations and Insights

# %%
#### ************** Final Observations **************

##1. Of all the treatments included in this study, Capomulin and Ramicane were associated with the lowest tumor volumes in mice

##2. Capomulin and Ramicane also had the highest total numbers of observations for tumor volume of all treatments, potentially increasing the robustness of these results

##3. For mice treated with Capomulin, an increase in mouse bodyweight of 1 g is associated with a 0.86mm3 increase in average tumor size

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_data_complete = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
study_data_complete
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice = study_data_complete["Mouse ID"].nunique()

print(f'{total_mice} mice were included in this study.')
# Out:
# 249 mice were included in this study.

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicates_df = study_data_complete[study_data_complete.duplicated(['Mouse ID', 'Timepoint'])]
duplicates_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 

#study_data_reduced_df = study_data_complete.drop_duplicates(subset = ['Mouse ID', 'Timepoint'], keep='first')
#study_data_reduced_df

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = study_data_complete.loc[study_data_complete['Mouse ID']!='g989']
cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

grouped_drug_df = cleaned_df.groupby('Drug Regimen')
grouped_drug_df.count()
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

mean_tumvol = grouped_drug_df['Tumor Volume (mm3)'].mean()
mean_tumvol

var_tumvol = grouped_drug_df['Tumor Volume (mm3)'].var()
var_tumvol

stddev_tumvol = grouped_drug_df['Tumor Volume (mm3)'].std()
stddev_tumvol

sem_tumvol = grouped_drug_df['Tumor Volume (mm3)'].sem()
sem_tumvol



# Assemble the resulting series into a single summary dataframe.
groupby_sum_df = pd.DataFrame({'Mean Tumor Volume (mm3)': mean_tumvol, 
                              'Variance Tumor Volume (mm3)': var_tumvol, 
                              'Standard Deviation Tumor Volume (mm3)': stddev_tumvol, 
                              'SEM Tumor Volume (mm3)': sem_tumvol})

groupby_sum_df
# Out:
#               Mean Tumor Volume (mm3)  Variance Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                   40.675741                    24.947764
# Ceftamin                    52.591172                    39.290177
# Infubinol                   52.884795                    43.128684
# Ketapril                    55.235638                    68.553577
# Naftisol                    54.331565                    66.173479
# Placebo                     54.033581                    61.168083
# Propriva                    52.320930                    43.852013
# Ramicane                    40.216745                    23.486704
# Stelasyn                    54.233149                    59.450562
# Zoniferol                   53.236507                    48.533355
#
#               Standard Deviation Tumor Volume (mm3)  SEM Tumor Volume (mm3)
# Drug Regimen
# Capomulin                                  4.994774                0.329346
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
#grouped_drug_df.count()
# Using the aggregation method, produce the same summary statistics in a single line
agg_sum_df = grouped_drug_df.agg({'Tumor Volume (mm3)': ['mean', 'sum', 'std', 'sem']})

agg_sum_df
# Out:
#              Tumor Volume (mm3)
#                            mean           sum       std       sem
# Drug Regimen
# Capomulin             40.675741   9355.420462  4.994774  0.329346
# Ceftamin              52.591172   9361.228582  6.268188  0.469821
# Infubinol             52.884795   9413.493529  6.567243  0.492236
# Ketapril              55.235638  10384.299876  8.279709  0.603860
# Naftisol              54.331565  10105.671026  8.134708  0.596466
# Placebo               54.033581   9780.078122  7.821003  0.581331
# Propriva              52.320930   7743.497619  6.622085  0.544332
# Ramicane              40.216745   9169.417875  4.846308  0.320955
# Stelasyn              54.233149   9816.199991  7.710419  0.573111
# Zoniferol             53.236507   9689.044192  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

drug_timepoints = grouped_drug_df['Timepoint'].count()

pandas_barchart = drug_timepoints.plot(kind="bar", facecolor="red", figsize=(8,6),
                                title="Timepoints per Drug",
                                xlabel="Drug Regimen",
                                ylabel="# of Timepoints")

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
xticklabels = drug_timepoints.index

pyplot_barchart = plt.bar(xticklabels, drug_timepoints)
plt.xticks(rotation=45)
plt.xlabel('Drug Regimen')
plt.ylabel('Timepoints')
plt.title('Timepoints per Drug')
# Out:
# Text(0.5, 1.0, 'Timepoints per Drug')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

mouse_metadata_reduced = mouse_metadata.loc[mouse_metadata['Mouse ID']!='g989']
mouse_sex = mouse_metadata_reduced['Sex'].value_counts()

mouse_sex

mouse_sex_pandas_pie = mouse_sex.plot(kind='pie', autopct='%1.1f%%', title = "Distribution of male and female mice in study")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

mouse_sex

labels = 'Male', 'Female'
mouse_sex_pyplot_pie = plt.pie(mouse_sex, labels = labels, autopct='%1.1f%%')
plt.title("Distribution of male and female mice in study")
# Out:
# Text(0.5, 1.0, 'Distribution of male and female mice in study')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
cleaned_df

df = cleaned_df.groupby('Mouse ID')
final_timepoint = df['Timepoint'].max()
final_timepoint

final_timepoint_df = pd.DataFrame(final_timepoint)
final_timepoint_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

merge_df = pd.merge(cleaned_df, final_timepoint_df, on=['Mouse ID','Timepoint'], how='inner')
merge_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
         
# Create empty list to fill with tumor vol data (for plotting)
tum_vol = []

for drug in drugs:
    
    drug_loc = merge_df.loc[merge_df['Drug Regimen']== drug]
    
    tum_vol.append(drug_loc['Tumor Volume (mm3)'])

      
       
        
# Calculate the IQR and upper/lower bounds for each drug to quantitatively determine if there are any potential outliers. 

#Calculating upper/lower bounds for Capomulin
quartiles_capomulin = tum_vol[0].quantile([.25,.5,.75])
lowerq_capomulin = quartiles_capomulin[.25]
lowerq_capomulin
upperq_capomulin = quartiles_capomulin [.75]
upperq_capomulin

iqr_capomulin = upperq_capomulin - lowerq_capomulin
    
low_bound_capomulin = lowerq_capomulin - (1.5*iqr_capomulin)
upper_bound_capomulin = upperq_capomulin + (1.5*iqr_capomulin)

print('------------------------------')
print(f"Values below {low_bound_capomulin} could be outliers for capomulin.")
print(f"Values above {upper_bound_capomulin} could be outliers for capomulin.")


#Calculating upper/lower bounds for Ramicane
quartiles_ramicane = tum_vol[1].quantile([.25,.5,.75])
lowerq_ramicane = quartiles_ramicane[.25]
upperq_ramicane = quartiles_ramicane [.75]

iqr_ramicane = upperq_ramicane - lowerq_ramicane
low_bound_ramicane = lowerq_ramicane - (1.5*iqr_ramicane)
upper_bound_ramicane = upperq_ramicane + (1.5*iqr_ramicane)

print('------------------------------')
print(f"Values below {low_bound_ramicane} could be outliers for ramicane.")
print(f"Values above {upper_bound_ramicane} could be outliers for ramicane.")


#Calculating upper/lower bounds for Infubinol
quartiles_infubinol = tum_vol[2].quantile([.25,.5,.75])
lowerq_infubinol = quartiles_infubinol[.25]
upperq_infubinol = quartiles_infubinol[.75]

iqr_infubinol = upperq_infubinol - lowerq_infubinol
low_bound_infubinol = lowerq_infubinol - (1.5*iqr_infubinol)
upper_bound_infubinol = upperq_infubinol + (1.5*iqr_infubinol)

print('------------------------------')
print(f"Values below {low_bound_infubinol} could be outliers for infubinol.")
print(f"Values above {upper_bound_infubinol} could be outliers for infubinol.")

#Calculating upper/lower bounds for Ceftamin
quartiles_ceftamin = tum_vol[3].quantile([.25,.5,.75])
lowerq_ceftamin = quartiles_ceftamin[.25]
upperq_ceftamin = quartiles_ceftamin[.75]

iqr_ceftamin = upperq_ceftamin - lowerq_ceftamin
low_bound_ceftamin = lowerq_ceftamin - (1.5*iqr_ceftamin)
upper_bound_ceftamin = upperq_ceftamin + (1.5*iqr_ceftamin)

print('------------------------------')
print(f"Values below {low_bound_ceftamin} could be outliers for ceftamin.")
print(f"Values above {upper_bound_ceftamin} could be outliers for ceftamin.")
# Out:
# ------------------------------
# Values below 20.70456164999999 could be outliers for capomulin.
# Values above 51.83201549 could be outliers for capomulin.
# ------------------------------
# Values below 17.912664470000003 could be outliers for ramicane.
# Values above 54.30681135 could be outliers for ramicane.
# ------------------------------
# Values below 36.83290494999999 could be outliers for infubinol.
# Values above 82.74144559000001 could be outliers for infubinol.
# ------------------------------
# Values below 25.355449580000002 could be outliers for ceftamin.
# Values above 87.66645829999999 could be outliers for ceftamin.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tumvol_boxplot = plt.boxplot(tum_vol, labels=drugs, flierprops={'marker': '^', 'markersize': 8, 'markerfacecolor': 'turquoise'})
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
cleaned_df.head(50)

mouse_iso = cleaned_df.loc[cleaned_df['Mouse ID'] == 's185']
mouse_iso

x_values = mouse_iso['Timepoint']
y_values = mouse_iso['Tumor Volume (mm3)']

mouse_iso_scatter = plt.plot(x_values, y_values)
plt.xlabel('Timepoints')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Change in Tumor Volume over Time for Mouse Treated with Capomulin')
plt.show()

# %%
## Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Capomulin']
capomulin_df

weight_df = capomulin_df.groupby('Weight (g)')

weight_df.count()

scatter_df = pd.DataFrame(weight_df['Tumor Volume (mm3)'].mean()).reset_index()
scatter_df

x_values = scatter_df['Weight (g)']
y_values = scatter_df['Tumor Volume (mm3)']

x_values

y_values

scatterplot = plt.scatter(x_values, y_values)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Relationship of Mouse Weight vs. Average Tumor Volume')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.annotate(line_eq, (19,37), fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Relationship of Mouse Weight vs. Average Tumor Volume for Mice Treated with Capomulin')
# Out:
# Text(0.5, 1.0, 'Relationship of Mouse Weight vs. Average Tumor Volume for Mice Treated with Capomulin')
